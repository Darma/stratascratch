# %%
import pandas as pd

# Task
# Find distinct LA neighborhoods

# DataFrames:
# airbnb_search_details


#solution: 
# Filter LA, drop nulls, get unique neighbourhoods

result = (
    airbnb_search_details
    .query("city == 'LA'")
    .dropna(subset=['neighbourhood'])
    ['neighbourhood']
    .unique()
)
