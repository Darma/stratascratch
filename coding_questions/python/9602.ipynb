# %%
import pandas as pd

# Task
# Find Netherlands hotels with dirty room complaints

# DataFrames:
# hotel_reviews


# Solution: 
# 1. Create mask for hotel_address containing 'netherlands' (convert to lowercase first)
# 2. Create mask for negative_review containing 'dirty' (convert to lowercase first)
# 3. Combine both masks using & operator and filter using .loc to return all columns

mask_country = hotel_reviews['hotel_address'].str.lower().str.contains('netherlands')
mask_dirty = hotel_reviews['negative_review'].str.lower().str.contains('dirty')
result = hotel_reviews.loc[mask_country & mask_dirty]
