# %%
import pandas as pd

# Task
# Format 'review_date' to YYYY/MM/DD and remove any NULL

# DataFrames:
# hotel_reviews

# Expected output: 
# review_date	nice_review_date
# 2017-07-05	2017/07/05
# 2015-08-29	2015/08/29
# 2017-05-23	2017/05/23
# 2016-08-25	2016/08/25
# 2015-09-17	2015/09/17


# Solution 
# 1: Remove NULL values from review_date column
# 2: Convert review_date to datetime format (if not already)
# 3: Format the date to YYYY/MM/DD using strftime
# 4: Select only the required columns for output

df_clean = hotel_reviews.dropna(subset=['review_date'])
df_clean['review_date'] = pd.to_datetime(df_clean['review_date'])
df_clean['nice_review_date'] = df_clean['review_date'].dt.strftime('%Y/%m/%d')
result = df_clean[['review_date', 'nice_review_date']]
